# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, precision_recall_fscore_support
import warnings
import os

# %%
df_encoded = pd.read_csv("Data/data_encoded")

# %%
df_encoded.head()
# Out:
#    Unnamed: 0  pct_tl_open_L6M  pct_tl_closed_L6M  Tot_TL_closed_L12M  \
# 0           0            0.000                0.0                   0
# 1           1            0.000                0.0                   0
# 2           2            0.125                0.0                   0
# 3           3            0.000                0.0                   0
# 4           4            0.000                0.0                   1
#
#    pct_tl_closed_L12M  Tot_Missed_Pmnt  CC_TL  Home_TL  PL_TL  Secured_TL  \
# 0               0.000                0      0        0      4           1
# 1               0.000                0      0        0      0           0
# 2               0.000                1      0        0      0           2
# 3               0.000                0      0        0      0           3
# 4               0.167                0      0        0      0           6
#
#    ...  last_prod_enq2_ConsumerLoan  last_prod_enq2_HL  last_prod_enq2_PL  \
# 0  ...                        False              False               True
# 1  ...                         True              False              False
# 2  ...                         True              False              False
# 3  ...                        False              False              False
# 4  ...                         True              False              False
#
#    last_prod_enq2_others  first_prod_enq2_AL  first_prod_enq2_CC  \
# 0                  False               False               False
# 1                  False               False               False
# 2                  False               False               False
# 3                  False                True               False
# 4                  False               False               False
#
#    first_prod_enq2_ConsumerLoan  first_prod_enq2_HL  first_prod_enq2_PL  \
# 0                         False               False                True
# 1                          True               False               False
# 2                         False               False               False
# 3                         False               False               False
# 4                         False               False                True
#
#    first_prod_enq2_others
# 0                   False
# 1                   False
# 2                    True
# 3                   False
# 4                   False
#
# [5 rows x 56 columns]

# %% [markdown]
# ## Random Forest

# %%
y = df_encoded['Approved_Flag']
x = df_encoded.drop( ['Approved_Flag'], axis = 1 )

# Splitting the Dataset
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)


# Initializing RandomForest Object
rf_classifier = RandomForestClassifier(n_estimators = 200, random_state=42)


# Model Fitting
rf_classifier.fit(x_train, y_train)


# Model Prediction
y_pred = rf_classifier.predict(x_test)



accuracy = accuracy_score(y_test, y_pred)
print ()
print(f'Accuracy: {accuracy}')
print ()
precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred)


for i, v in enumerate(['p1', 'p2', 'p3', 'p4']):
    print(f"Class {v}:")
    print(f"Precision: {precision[i]}")
    print(f"Recall: {recall[i]}")
    print(f"F1 Score: {f1_score[i]}")
    print()
# Out:
# Accuracy: 0.7676215380958041
#
# Class p1:
# Precision: 0.8399532710280374
# Recall: 0.7090729783037475
# F1 Score: 0.7689839572192514
#
# Class p2:
# Precision: 0.7966762760725793
# Recall: 0.931219028741328
# F1 Score: 0.8587095594955219
#
# Class p3:
# Precision: 0.4561128526645768
# Recall: 0.21962264150943397
# F1 Score: 0.29648497198166074
#
# Class p4:
# Precision: 0.7338551859099804
# Recall: 0.7288629737609329
# F1 Score: 0.7313505607020966

# %%
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder

xgb_classifier = xgb.XGBClassifier(objective='multi:softmax',  num_class=4)



y = df_encoded['Approved_Flag']
x = df_encoded. drop ( ['Approved_Flag'], axis = 1 )


label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)


x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42)




xgb_classifier.fit(x_train, y_train)
y_pred = xgb_classifier.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print ()
print(f'Accuracy: {accuracy:.2f}')
print ()

precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred)

for i, v in enumerate(['p1', 'p2', 'p3', 'p4']):
    print(f"Class {v}:")
    print(f"Precision: {precision[i]}")
    print(f"Recall: {recall[i]}")
    print(f"F1 Score: {f1_score[i]}")
    print()
# Out:
# Accuracy: 0.77
#
# Class p1:
# Precision: 0.8224789915966386
# Recall: 0.772189349112426
# F1 Score: 0.7965412004069176
#
# Class p2:
# Precision: 0.8241305127285765
# Recall: 0.911199207135778
# F1 Score: 0.8654805610467853
#
# Class p3:
# Precision: 0.4538922155688623
# Recall: 0.2860377358490566
# F1 Score: 0.3509259259259259
#
# Class p4:
# Precision: 0.7213740458015268
# Recall: 0.7346938775510204
# F1 Score: 0.7279730380356283

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier


y = df_encoded['Approved_Flag']
x = df_encoded. drop ( ['Approved_Flag'], axis = 1 )

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)


dt_model = DecisionTreeClassifier(max_depth=20, min_samples_split=10)
dt_model.fit(x_train, y_train)
y_pred = dt_model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print ()
print(f"Accuracy: {accuracy:.2f}")
print ()

precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred)

for i, v in enumerate(['p1', 'p2', 'p3', 'p4']):
    print(f"Class {v}:")
    print(f"Precision: {precision[i]}")
    print(f"Recall: {recall[i]}")
    print(f"F1 Score: {f1_score[i]}")
    print()
# Out:
# Accuracy: 0.71
#
# Class p1:
# Precision: 0.7316582914572864
# Recall: 0.717948717948718
# F1 Score: 0.7247386759581882
#
# Class p2:
# Precision: 0.8097826086956522
# Recall: 0.8269573835480674
# F1 Score: 0.8182798862410513
#
# Class p3:
# Precision: 0.3387358184764992
# Recall: 0.3154716981132075
# F1 Score: 0.3266901133255178
#
# Class p4:
# Precision: 0.6346899224806202
# Recall: 0.6365403304178814
# F1 Score: 0.6356137797185832

# %%
# XG boost is giving better accuracy so let's fine tune that
# Hyperperamater tuning
# Hyperparameter tuning in xgboost
from sklearn.model_selection import GridSearchCV
x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42)

# Define the XGBClassifier with the initial set of hyperparameters
xgb_model = xgb.XGBClassifier(objective='multi:softmax', num_class=4)

# Define the parameter grid for hyperparameter tuning

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
}

grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, cv=3, scoring='accuracy', n_jobs=-1)
grid_search.fit(x_train, y_train)

# Print the best hyperparameters
print("Best Hyperparameters:", grid_search.best_params_)

# Evaluate the model with the best hyperparameters on the test set
best_model = grid_search.best_estimator_
accuracy = best_model.score(x_test, y_test)
print("Test Accuracy:", accuracy)

# Best Hyperparameters: {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 200}
# Out:
# Best Hyperparameters: {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 200}
# Test Accuracy: 0.782241768691311

# %%
xgb_classifier = xgb.XGBClassifier(objective='multi:softmax',
                                   num_class = 4, 
                                   colsample_by_tree = 0.9, 
                                   learning_rate = 1,
                                   max_depth = 3,
                                   alpha = 10,
                                   n_estimators = 100
                                  )


y = df_encoded['Approved_Flag']
x = df_encoded. drop ( ['Approved_Flag'], axis = 1 )


label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)


x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42)




xgb_classifier.fit(x_train, y_train)
y_pred = xgb_classifier.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print ()
print(f'Accuracy: {accuracy:.2f}')
print ()

precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred)

for i, v in enumerate(['p1', 'p2', 'p3', 'p4']):
    print(f"Class {v}:")
    print(f"Precision: {precision[i]}")
    print(f"Recall: {recall[i]}")
    print(f"F1 Score: {f1_score[i]}")
    print()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:200: UserWarning: [13:43:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "colsample_by_tree" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Accuracy: 0.78
#
# Class p1:
# Precision: 0.8338624338624339
# Recall: 0.777120315581854
# F1 Score: 0.8044920877998979
#
# Class p2:
# Precision: 0.8244642857142858
# Recall: 0.915163528245788
# F1 Score: 0.8674495068107092
#
# Class p3:
# Precision: 0.45892018779342725
# Recall: 0.29509433962264153
# F1 Score: 0.3592099219108865
#
# Class p4:
# Precision: 0.7332677165354331
# Recall: 0.7240038872691934
# F1 Score: 0.7286063569682152
